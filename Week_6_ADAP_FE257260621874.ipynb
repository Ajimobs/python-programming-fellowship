# %% [markdown]
# <a href="https://colab.research.google.com/github/Ajimobs/python-programming-fellowship/blob/main/Week_6_ADAP_FE257260621874.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a252b457-fd1a-4403-9daf-bdff4aa7c2f3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a252b457-fd1a-4403-9daf-bdff4aa7c2f3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.histplot(df['Cholesterol_Level'], kde=True, color='mediumseagreen', bins=30, edgecolor='black')
plt.title('Cholesterol Level Distribution', fontsize=16)
plt.xlabel('Cholesterol Level', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3d943bfaaa3f> in <cell line: 0>()
#       3
#       4 plt.figure(figsize=(10, 6))
# ----> 5 sns.histplot(df['Cholesterol_Level'], kde=True, color='mediumseagreen', bins=30, edgecolor='black')
#       6 plt.title('Cholesterol Level Distribution', fontsize=16)
#       7 plt.xlabel('Cholesterol Level', fontsize=12)
#
# NameError: name 'df' is not defined

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 20 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Patient_ID                    100000 non-null  int64
#  1   Age                           100000 non-null  int64
#  2   Gender                        100000 non-null  object
#  3   Cholesterol_Level             100000 non-null  int64
#  4   Blood_Pressure_Systolic       100000 non-null  int64
#  5   Blood_Pressure_Diastolic      100000 non-null  int64
#  6   Smoking_Status                100000 non-null  object
#  7   Alcohol_Intake                100000 non-null  object
#  8   Physical_Activity             100000 non-null  object
#  9   Obesity_Index                 100000 non-null  float64
#  10  Diabetes_Status               100000 non-null  object
#  11  Family_History_Heart_Disease  100000 non-null  object
# ...

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Age', y='Cholesterol_Level', data=df, color='tomato', alpha=0.5, s=30, label='Patients')
sns.lineplot(x='Age', y='Cholesterol_Level', data=df.sort_values('Age'), color='navy', label='Trend')
plt.title('Age vs. Cholesterol Level', fontsize=16)
plt.xlabel('Age', fontsize=12)
plt.ylabel('Cholesterol Level', fontsize=12)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

sns.barplot(x='Gender', y='Cholesterol_Level', data=df, ax=axes[0], palette='pastel', ci='sd')
axes[0].set_title('Average Cholesterol by Gender', fontsize=14)
axes[0].set_xlabel('Gender')
axes[0].set_ylabel('Cholesterol Level')
axes[0].grid(True)

sns.scatterplot(x='Age', y='Blood_Pressure_Systolic', data=df, ax=axes[1], color='slateblue', alpha=0.4, s=25)
axes[1].set_title('Blood Pressure (Systolic) vs Age', fontsize=14)
axes[1].set_xlabel('Age')
axes[1].set_ylabel('Systolic Blood Pressure')
axes[1].grid(True)

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-10-9fad27d4c0bc>:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(x='Gender', y='Cholesterol_Level', data=df, ax=axes[0], palette='pastel', ci='sd')
# <ipython-input-10-9fad27d4c0bc>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Gender', y='Cholesterol_Level', data=df, ax=axes[0], palette='pastel', ci='sd')
